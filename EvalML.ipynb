# %%
# !pip install evalml

# %%
import evalml

# %%
from urllib.request import urlopen

# %%
import pandas as pd

# %%
input_data = urlopen('https://featurelabs-static.s3.amazonaws.com/spam_text_messages_modified.csv')

# %%
data = pd.read_csv('https://featurelabs-static.s3.amazonaws.com/spam_text_messages_modified.csv')

# %%
data
# Out:
#      Category                                            Message
# 0        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 1        spam  FreeMsg Hey there darling it's been 3 week's n...
# 2        spam  WINNER!! As a valued network customer you have...
# 3        spam  Had your mobile 11 months or more? U R entitle...
# 4        spam  SIX chances to win CASH! From 100 to 20,000 po...
# ...       ...                                                ...
# 2984     spam  This is the 2nd time we have tried 2 contact u...
# 2985      ham               Will ü b going to esplanade fr home?
# 2986      ham  Pity, * was in mood for that. So...any other s...
# 2987      ham  The guy did some bitching but I acted like i'd...
# 2988      ham                         Rofl. Its true to its name
#
# [2989 rows x 2 columns]

# %%
X = data['Message']

# %%
y = data['Category']

# %%
y.value_counts(normalize=True)
# Out:
# ham     0.750084
# spam    0.249916
# Name: Category, dtype: float64

# %%
X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(X, y, problem_type='binary')

# %%
evalml.problem_types.ProblemTypes.all_problem_types
# Out:
# [<ProblemTypes.BINARY: 'binary'>,
#  <ProblemTypes.MULTICLASS: 'multiclass'>,
#  <ProblemTypes.REGRESSION: 'regression'>,
#  <ProblemTypes.TIME_SERIES_REGRESSION: 'time series regression'>,
#  <ProblemTypes.TIME_SERIES_BINARY: 'time series binary'>,
#  <ProblemTypes.TIME_SERIES_MULTICLASS: 'time series multiclass'>]

# %%
X_train.head()
# Out:
# 562         Haha I heard that, text me when you're around
# 1253    I'm thinking that chennai forgot to come for a...
# 1816    Can you tell Shola to please go to college of ...
# 2054                           K k pa Had your lunch aha.
# 511     staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323
# Name: Message, dtype: string

# %%
X_train.dtype
# Out:
# string[python]

# %%
from evalml import AutoMLSearch

# %%
automl = AutoMLSearch(X_train=X_train,y_train=y_train, problem_type='binary',max_batches=1, optimize_thresholds=True )
# Out:
# Generating pipelines to search over...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-958df9f2a0f5> in <module>()
# ----> 1 automl = AutoMLSearch(X_train=X_train,y_train=y_train, problem_type='binary',max_batches=1, optimize_thresholds=True )
#
# /usr/local/lib/python3.7/dist-packages/evalml/automl/automl_search.py in __init__(self, X_train, y_train, problem_type, objective, max_iterations, max_time, patience, tolerance, data_splitter, allowed_component_graphs, allowed_model_families, start_iteration_callback, add_result_callback, error_callback, additional_objectives, alternate_thresholding_objective, random_seed, n_jobs, tuner_class, optimize_thresholds, ensembling, max_batches, problem_configuration, train_best_pipeline, pipeline_parameters, custom_hyperparameters, sampler_method, sampler_balanced_ratio, _ensembling_split_size, _pipelines_per_batch, engine)
#     525             )
#     526             index_and_unknown_columns = list(
# --> 527                 self.X_train.ww.select(["index", "unknown"], return_schema=True).columns
#     528             )
#     529             unknown_columns = list(
#
# /usr/local/lib/python3.7/dist-packages/woodwork/column_accessor.py in __getattr__(self, attr)
#     237             return self._make_series_call(attr)
#     238         else:
# --> 239             raise AttributeError(f"Woodwork has no attribute '{attr}'")
#     240
#     241     def __repr__(self):
#
# AttributeError: Woodwork has no attribute 'select'
