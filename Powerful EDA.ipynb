# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/AI/ML/Datasets/AHPP/train.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
# !pip install sweetviz

# %%
test = pd.read_csv('/content/drive/MyDrive/AI/ML/Datasets/AHPP/test.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
import sweetviz

# %%
report = sweetviz.analyze([train,"Train"], target_feat='SalePrice')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_html('/content/drive/MyDrive/AI/ML/Datasets/AHPP/Report.html')
# Out:
# Report /content/drive/MyDrive/AI/ML/Datasets/AHPP/Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
cmp_report = sweetviz.compare([train,"Train"], [test,"Test"], target_feat="SalePrice")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
cmp_report.show_html('/content/drive/MyDrive/AI/ML/Datasets/AHPP/Comparision_Report.html')
# Out:
# Report /content/drive/MyDrive/AI/ML/Datasets/AHPP/Comparision_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
