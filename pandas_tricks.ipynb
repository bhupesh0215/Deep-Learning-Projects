# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
pd.show_versions()
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# INSTALLED VERSIONS
# ------------------
# commit           : b5958ee1999e9aead1938c0bba2b674378807b3d
# python           : 3.7.10.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 4.19.112+
# Version          : #1 SMP Thu Jul 23 08:00:38 PDT 2020
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.1.5
# numpy            : 1.19.5
# pytz             : 2018.9
# dateutil         : 2.8.1
# pip              : 19.3.1
# setuptools       : 53.0.0
# Cython           : 0.29.22
# ...

# %%
df = pd.DataFrame({'col one':[0,1], 'col two':[1,0]})
df
# Out:
#    col one  col two
# 0        0        1
# 1        1        0

# %%
df = pd.DataFrame(np.random.rand(2,4))
df
# Out:
#           0         1         2         3
# 0  0.480819  0.464865  0.163054  0.405445
# 1  0.639823  0.653119  0.740740  0.120296

# %%
df = pd.DataFrame(np.random.rand(2,4), columns=list('abcd'))
df
# Out:
#           a         b         c         d
# 0  0.131082  0.023012  0.167911  0.415440
# 1  0.357983  0.171060  0.896725  0.853211

# %% [markdown]
# ## Rename columns

# %%
df = pd.DataFrame({'col one':[0,1], 'col two':[1,0]})
df
# Out:
#    col one  col two
# 0        0        1
# 1        1        0

# %%
df = df.rename({'col one':'col_one', 'col two':'col_two'},axis='columns')
df
# Out:
#    col_one  col_two
# 0        0        1
# 1        1        0

# %%
df = pd.DataFrame({'col one':[0,1], 'col two':[1,0]})
df
# Out:
#    col one  col two
# 0        0        1
# 1        1        0

# %%
df.columns = ['col_one','col_two']
df
# Out:
#    col_one  col_two
# 0        0        1
# 1        1        0

# %%
df = pd.DataFrame({'col one':[0,1], 'col two':[1,0]})
df
# Out:
#    col one  col two
# 0        0        1
# 1        1        0

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df
# Out:
#    col_one  col_two
# 0        0        1
# 1        1        0

# %%
df = df.add_prefix('X_')
df
# Out:
#    X_col_one  X_col_two
# 0          0          1
# 1          1          0

# %%
df = df.add_suffix('_Y')
df
# Out:
#    X_col_one_Y  X_col_two_Y
# 0            0            1
# 1            1            0

# %%
df.loc[::-1].head()
# Out:
#    X_col_one_Y  X_col_two_Y
# 1            1            0
# 0            0            1

# %%
df.loc[::-1].reset_index(drop=True).head()
# Out:
#    X_col_one_Y  X_col_two_Y
# 0            1            0
# 1            0            1

# %%
df.head()
# Out:
#    X_col_one_Y  X_col_two_Y
# 0            0            1
# 1            1            0

# %%
df.loc[:,::-1].head()
# Out:
#    X_col_two_Y  X_col_one_Y
# 0            1            0
# 1            0            1

# %%
df = pd.DataFrame({'col one':[0,1], 'col two':[1.0,2.0], 'col three':['a','b']})
df
# Out:
#    col one  col two col three
# 0        0      1.0         a
# 1        1      2.0         b

# %%
df.dtypes
# Out:
# col one        int64
# col two      float64
# col three     object
# dtype: object

# %%
df.select_dtypes(include=['float','object'])
# Out:
#    col two col three
# 0      1.0         a
# 1      2.0         b

# %%
df.select_dtypes(exclude=['object'])
# Out:
#    col one  col two
# 0        0      1.0
# 1        1      2.0

# %%
df = pd.DataFrame({'col one':['0','1'], 'col two':['1.0','2.0'], 'col three':['a','b']})
df
# Out:
#   col one col two col three
# 0       0     1.0         a
# 1       1     2.0         b

# %%
df.dtypes
# Out:
# col one      object
# col two      object
# col three    object
# dtype: object

# %%
df.astype({'col one':'int', 'col two':'float'}).dtypes
# Out:
# col one        int64
# col two      float64
# col three     object
# dtype: object

# %%
df = pd.DataFrame({'col one':['0','-'], 'col two':['1.0','2.0'], 'col three':['a','b']})
df
# Out:
#   col one col two col three
# 0       0     1.0         a
# 1       -     2.0         b

# %%
# df.astype({'col one':int, 'col two':float}).dtypes
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#   col_one col_two col_three
# 0       0     1.0         a
# 1       -     2.0         b

# %%
pd.to_numeric(df.col_one, errors='coerce')
df.dtypes
# Out:
# col_one      object
# col_two      object
# col_three    object
# dtype: object

# %%
df = pd.DataFrame({'col one':['0','-'], 'col two':['1.0','2.0']})
df.dtypes
# Out:
# col one    object
# col two    object
# dtype: object

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
df
# Out:
#    col one  col two
# 0      0.0      1.0
# 1      NaN      2.0

# %%
df.fillna(0)
# Out:
#    col one  col two
# 0      0.0      1.0
# 1      0.0      2.0

# %%
df = pd.DataFrame({'col_one':['0','-'], 'col_two':['1.0','2.0']})
df.dtypes
# Out:
# col_one    object
# col_two    object
# dtype: object

# %%
pd.to_numeric(df.col_one, errors='coerce').fillna(0)
# Out:
# 0    0.0
# 1    0.0
# Name: col_one, dtype: float64

# %%
df
# Out:
#   col_one col_two
# 0       0     1.0
# 1       -     2.0

# %%
drinks = pd.read_csv('https://bit.ly/drinksbycountry')

# %%
drinks.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 30.5 KB

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
columns = ['country', 'beer_servings']
small_drinks = pd.read_csv('https://bit.ly/drinksbycountry', usecols=columns)

# %%
small_drinks.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        193 non-null    object
#  1   beer_servings  193 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 13.9 KB
