# %%
from keras.layers import Dense, Lambda, Input, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = [224,224]

# %%
train_path = '/content/drive/MyDrive/AI/DL/VGG16/Train'
test_path = '/content/drive/MyDrive/AI/DL/VGG16/Test'

# %%
# vgg = VGG16(input_shape=IMAGE_SIZE+[3],weights='imagenet',include_top=False)
vgg = ResNet50(input_shape=IMAGE_SIZE+[3],weights='imagenet',include_top=False)
# Out:
# ...
# 94773248/94765736 [==============================] - 0s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
folders = glob(train_path+'/*')

# %%
folders
# Out:
# ['/content/drive/MyDrive/AI/DL/VGG16/Train/cats',
#  '/content/drive/MyDrive/AI/DL/VGG16/Train/dogs']

# %%
x = Flatten()(vgg.output)

# %%
x
# Out:
# <KerasTensor: shape=(None, 100352) dtype=float32 (created by layer 'flatten_1')>

# %%
prediction = Dense(len(folders),activation='softmax')(x)

# %%
prediction
# Out:
# <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'dense_1')>

# %%
model = Model(inputs=vgg.input,outputs=prediction)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2,horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
traing_set = train_datagen.flow_from_directory(train_path,target_size=(224,224),batch_size=32,class_mode='categorical')
# Out:
# Found 208 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(test_path,target_size=(224,224),batch_size=32,class_mode='categorical')
# Out:
# Found 52 images belonging to 2 classes.

# %%
r = model.fit_generator(traing_set, validation_data=test_set,epochs=5,steps_per_epoch=len(traing_set),validation_steps=len(test_set))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/5
# 7/7 [==============================] - 7s 622ms/step - loss: 4.9746 - accuracy: 0.4870 - val_loss: 4.7888 - val_accuracy: 0.6346
# Epoch 2/5
# 7/7 [==============================] - 3s 450ms/step - loss: 4.9833 - accuracy: 0.5001 - val_loss: 1.3397 - val_accuracy: 0.6346
# Epoch 3/5
# 7/7 [==============================] - 3s 445ms/step - loss: 3.3018 - accuracy: 0.5468 - val_loss: 4.2111 - val_accuracy: 0.4038
# Epoch 4/5
# 7/7 [==============================] - 3s 450ms/step - loss: 2.5629 - accuracy: 0.5692 - val_loss: 0.9899 - val_accuracy: 0.6346
# Epoch 5/5
# ...

# %%
r.history['loss']
# Out:
# [6.055418968200684,
#  4.861462593078613,
#  3.373546838760376,
#  2.1908199787139893,
#  1.1887809038162231]

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label = 'test loss')
plt.legend()
plt.show()
plt.savefig('/content/drive/MyDrive/AI/DL/VGG16/valloss_loss')

# %%
plt.plot(r.history['accuracy'],label ='train acc')
plt.plot(r.history['val_accuracy'],label='test acc')
plt.legend()
plt.show()
plt.savefig('/content/drive/MyDrive/AI/DL/VGG16/ValAcc_Acc')

# %%
model.save('/content/drive/MyDrive/AI/DL/VGG16/model.h5')
