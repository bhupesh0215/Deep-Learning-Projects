# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent =   ['the glass of milk', 'the glass of juice', 'the cup of tea', 'I am a good boy', 'I am a good developer', 'understand the meaning of word', 'your videos are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of word',
#  'your videos are good']

# %%
voc_size = 10000

# %%
one_hot_repr = [one_hot(word, voc_size) for word in sent]

# %%
one_hot_repr
# Out:
# [[9344, 6635, 8902, 2997],
#  [9344, 6635, 8902, 8357],
#  [9344, 3484, 8902, 2964],
#  [2236, 5550, 1886, 6061, 2326],
#  [2236, 5550, 1886, 6061, 5798],
#  [879, 9344, 781, 8902, 2419],
#  [3025, 3605, 7738, 6061]]

# %%
one_hot('i am a good boy', 1000)
# Out:
# [400, 789, 653, 454, 490]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import numpy as np

# %%
sent_length = 8

# %%
embeded_doc = pad_sequences(one_hot_repr, maxlen=sent_length, padding='pre')
embeded_doc
# Out:
# array([[   0,    0,    0,    0, 9344, 6635, 8902, 2997],
#        [   0,    0,    0,    0, 9344, 6635, 8902, 8357],
#        [   0,    0,    0,    0, 9344, 3484, 8902, 2964],
#        [   0,    0,    0, 2236, 5550, 1886, 6061, 2326],
#        [   0,    0,    0, 2236, 5550, 1886, 6061, 5798],
#        [   0,    0,    0,  879, 9344,  781, 8902, 2419],
#        [   0,    0,    0,    0, 3025, 3605, 7738, 6061]], dtype=int32)

# %%
model = Sequential()
dim = 10
model.add(Embedding(input_dim=voc_size, output_dim=dim,input_length=sent_length))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 8, 10)             100000
# ...
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
embeded_doc[0]
# Out:
# array([   0,    0,    0,    0, 9344, 6635, 8902, 2997], dtype=int32)

# %%
model.predict(embeded_doc)[0]
# Out:
# array([[ 0.01324637, -0.00221826, -0.03507072, -0.04814769,  0.01321108,
#          0.01285975,  0.00097619,  0.02384387, -0.0201336 , -0.0033368 ],
#        [ 0.01324637, -0.00221826, -0.03507072, -0.04814769,  0.01321108,
#          0.01285975,  0.00097619,  0.02384387, -0.0201336 , -0.0033368 ],
#        [ 0.01324637, -0.00221826, -0.03507072, -0.04814769,  0.01321108,
#          0.01285975,  0.00097619,  0.02384387, -0.0201336 , -0.0033368 ],
#        [ 0.01324637, -0.00221826, -0.03507072, -0.04814769,  0.01321108,
#          0.01285975,  0.00097619,  0.02384387, -0.0201336 , -0.0033368 ],
#        [-0.04471474, -0.00783256, -0.02635759,  0.03339498,  0.02951108,
#          0.03607481, -0.01651814,  0.04553688,  0.0156746 ,  0.01435651],
#        [ 0.03672491,  0.04329797, -0.00536115, -0.01790826, -0.01725236,
#          0.02761147, -0.01673373, -0.0113142 ,  0.0112865 ,  0.01565522],
#        [-0.02492349, -0.01556326, -0.02642932,  0.00842392,  0.03349349,
# ...
