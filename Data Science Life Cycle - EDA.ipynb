# %% [markdown]
# Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
dataset = pd.read_csv('/content/drive/MyDrive/AI/ML/HousePricePred/train.csv')

# %%
dataset.shape
# Out:
# (1460, 81)

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
features_with_na = [features for features in dataset.columns if dataset[features].isnull().sum() > 1]

# %%
for feature in features_with_na:
  print(feature, np.round(dataset[feature].isnull().mean(),4),' % missing values')
# Out:
# LotFrontage 0.1774  % missing values
# Alley 0.9377  % missing values
# MasVnrType 0.0055  % missing values
# MasVnrArea 0.0055  % missing values
# BsmtQual 0.0253  % missing values
# BsmtCond 0.0253  % missing values
# BsmtExposure 0.026  % missing values
# BsmtFinType1 0.0253  % missing values
# BsmtFinType2 0.026  % missing values
# FireplaceQu 0.4726  % missing values
# GarageType 0.0555  % missing values
# GarageYrBlt 0.0555  % missing values
# GarageFinish 0.0555  % missing values
# GarageQual 0.0555  % missing values
# GarageCond 0.0555  % missing values
# PoolQC 0.9952  % missing values
# Fence 0.8075  % missing values
# MiscFeature 0.963  % missing values

# %%
dataset.shape
# Out:
# (1460, 81)

# %%
dataset['BsmtCond'].isnull().mean()
# Out:
# 0.025342465753424658

# %%
37/1460
# Out:
# 0.025342465753424658

# %%
( True + True + False + False) / 4
# Out:
# 0.5

# %%
for feature in features_with_na:
  data = dataset.copy()
  data[feature] = np.where(data[feature].isnull(),1,0)
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.title(feature)
  plt.show()

# %%
len(dataset.Id)
# Out:
# 1460

# %%
numerical_features = [feature for feature in dataset.columns if dataset[feature].dtype != 'O']

# %%
len(numerical_features), numerical_features
# Out:
# (38,
#  ['Id',
#   'MSSubClass',
#   'LotFrontage',
#   'LotArea',
#   'OverallQual',
#   'OverallCond',
#   'YearBuilt',
#   'YearRemodAdd',
#   'MasVnrArea',
#   'BsmtFinSF1',
#   'BsmtFinSF2',
#   'BsmtUnfSF',
#   'TotalBsmtSF',
#   '1stFlrSF',
#   '2ndFlrSF',
#   'LowQualFinSF',
#   'GrLivArea',
#   'BsmtFullBath',
#   'BsmtHalfBath',
#   'FullBath',
#   'HalfBath',
#   'BedroomAbvGr',
#   'KitchenAbvGr',
#   'TotRmsAbvGrd',
#   'Fireplaces',
#   'GarageYrBlt',
#   'GarageCars',
#   'GarageArea',
#   'WoodDeckSF',
#   'OpenPorchSF',
#   'EnclosedPorch',
#   '3SsnPorch',
#   'ScreenPorch',
#   'PoolArea',
#   'MiscVal',
#   'MoSold',
#   'YrSold',
#   'SalePrice'])

# %%
year_feature = [feature for feature in dataset.columns if 'Yr' in feature or 'Year' in feature]

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title('House Price vs YearSold')
# Out:
# Text(0.5, 1.0, 'House Price vs YearSold')

# %%
for feature in year_feature:
  if feature != 'YrSold':
    data = dataset.copy()
    data[feature] = data['YrSold'] - data[feature]
    plt.scatter(data[feature],data['SalePrice'])
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.show()

# %%
discrete_feature = [feature for feature in numerical_features if len(dataset[feature].unique()) < 25 and feature not in year_feature + ['Id'] ]

# %%
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dataset[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
for feature in discrete_feature:
  dataset.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel('Sale Price')
  plt.show()

# %%
continuous_feature = [feature for feature in numerical_features if feature not in discrete_feature + year_feature + ['Id']]

# %%
len(continuous_feature), continuous_feature
# Out:
# (16,
#  ['LotFrontage',
#   'LotArea',
#   'MasVnrArea',
#   'BsmtFinSF1',
#   'BsmtFinSF2',
#   'BsmtUnfSF',
#   'TotalBsmtSF',
#   '1stFlrSF',
#   '2ndFlrSF',
#   'GrLivArea',
#   'GarageArea',
#   'WoodDeckSF',
#   'OpenPorchSF',
#   'EnclosedPorch',
#   'ScreenPorch',
#   'SalePrice'])

# %%
for feature in continuous_feature:
  data = dataset.copy()
  data[feature].hist(bins=25)
  plt.xlabel(feature)
  plt.ylabel('Count')
  plt.show()

# %%
for feature in continuous_feature:
  data = dataset.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    data['SalePrice'] = np.log(data['SalePrice'])
    plt.scatter(data[feature],data['SalePrice'])
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.title(feature)
    plt.show()

# %%
for feature in continuous_feature:
  data = dataset.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    data[feature].hist(bins=25)
    plt.show()

# %%
for feature in continuous_feature:
  data = dataset.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    data.boxplot(column=feature)
    plt.show()

# %%
categorical_feature = [feature for feature in dataset.columns if dataset[feature].dtype == 'O']

# %%
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_feature:
  print('feature - {}, unique cat - {}'.format(feature,len(dataset[feature].unique())))
# Out:
# feature - MSZoning, unique cat - 5
# feature - Street, unique cat - 2
# feature - Alley, unique cat - 3
# feature - LotShape, unique cat - 4
# feature - LandContour, unique cat - 4
# feature - Utilities, unique cat - 2
# feature - LotConfig, unique cat - 5
# feature - LandSlope, unique cat - 3
# feature - Neighborhood, unique cat - 25
# feature - Condition1, unique cat - 9
# feature - Condition2, unique cat - 8
# feature - BldgType, unique cat - 5
# feature - HouseStyle, unique cat - 8
# feature - RoofStyle, unique cat - 6
# feature - RoofMatl, unique cat - 8
# feature - Exterior1st, unique cat - 15
# feature - Exterior2nd, unique cat - 16
# feature - MasVnrType, unique cat - 5
# feature - ExterQual, unique cat - 4
# feature - ExterCond, unique cat - 5
# feature - Foundation, unique cat - 6
# feature - BsmtQual, unique cat - 5
# feature - BsmtCond, unique cat - 5
# feature - BsmtExposure, unique cat - 5
# feature - BsmtFinType1, unique cat - 7
# ...

# %%
for feature in categorical_feature:
  data = dataset.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel('Sale Price')
  plt.show()

# %% [markdown]
# Feature Engineering

# %%
dataset = pd.read_csv('/content/drive/MyDrive/AI/ML/HousePricePred/train.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
# X_train, X_test, y_train, y_test ()

# %%
feature_nan = [feature for feature in dataset.columns if dataset[feature].isnull().sum() > 1 and dataset[feature].dtype == 'O']

# %%
feature_nan
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for feature in feature_nan:
  print('Feature - {}, % Null values - {}'.format(feature, round(dataset[feature].isnull().mean(),4)))
# Out:
# Feature - Alley, % Null values - 0.9377
# Feature - MasVnrType, % Null values - 0.0055
# Feature - BsmtQual, % Null values - 0.0253
# Feature - BsmtCond, % Null values - 0.0253
# Feature - BsmtExposure, % Null values - 0.026
# Feature - BsmtFinType1, % Null values - 0.0253
# Feature - BsmtFinType2, % Null values - 0.026
# Feature - FireplaceQu, % Null values - 0.4726
# Feature - GarageType, % Null values - 0.0555
# Feature - GarageFinish, % Null values - 0.0555
# Feature - GarageQual, % Null values - 0.0555
# Feature - GarageCond, % Null values - 0.0555
# Feature - PoolQC, % Null values - 0.9952
# Feature - Fence, % Null values - 0.8075
# Feature - MiscFeature, % Null values - 0.963

# %%
def replace_nan_vals(dataset,features):
  data = dataset.copy()
  data = data[features].fillna('Missing')
  return data

# %%
dataset = replace_nan_vals(dataset,feature_nan)

# %%
dataset[feature_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
dataset.head()
# Out:
#      Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0  Missing    BrkFace       Gd       TA           No          GLQ
# 1  Missing       None       Gd       TA           Gd          ALQ
# 2  Missing    BrkFace       Gd       TA           Mn          GLQ
# 3  Missing       None       TA       Gd           No          ALQ
# 4  Missing    BrkFace       Gd       TA           Av          GLQ
#
#   BsmtFinType2 FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0          Unf     Missing     Attchd          RFn         TA         TA
# 1          Unf          TA     Attchd          RFn         TA         TA
# 2          Unf          TA     Attchd          RFn         TA         TA
# 3          Unf          Gd     Detchd          Unf         TA         TA
# 4          Unf          TA     Attchd          RFn         TA         TA
#
#     PoolQC    Fence MiscFeature
# 0  Missing  Missing     Missing
# 1  Missing  Missing     Missing
# ...

# %%
num_feat_nan = [feature for feature in dataset.columns if dataset[feature].isnull().sum() > 1 and dataset[feature].dtype != 'O']

# %%
num_feat_nan
# Out:
# []
