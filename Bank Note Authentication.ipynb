# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/ML/Datasets/Bank_Note_Auth/BankNote_Authentication.csv')

# %%
df.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    variance  skewness  curtosis  entropy
# 0   3.62160    8.6661   -2.8073 -0.44699
# 1   4.54590    8.1674   -2.4586 -1.46210
# 2   3.86600   -2.6383    1.9242  0.10645
# 3   3.45660    9.5228   -4.0112 -3.59440
# 4   0.32924   -4.4552    4.5718 -0.98880

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
y.dtype
# Out:
# dtype('int64')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((960, 4), (960,), (412, 4), (412,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acs = accuracy_score(y_test, y_pred)

# %%
acs
# Out:
# 0.9927184466019418

# %%
import pickle

# %%
pickle_file = open('/content/drive/MyDrive/AI/ML/Datasets/Bank_Note_Auth/Bank_Note_Auth_CLF.h5', 'wb')

# %%
pickle.dump(acs, pickle_file)

# %%
pickle_file.close()
