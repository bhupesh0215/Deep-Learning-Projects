# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/Using_Multi_Core_CPU/winequalityN.csv')

# %%
df.head()
# Out:
#     type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0  white            7.0              0.27  ...       0.45      8.8        6
# 1  white            6.3              0.30  ...       0.49      9.5        6
# 2  white            8.1              0.28  ...       0.44     10.1        6
# 3  white            7.2              0.23  ...       0.40      9.9        6
# 4  white            7.2              0.23  ...       0.40      9.9        6
#
# [5 rows x 13 columns]

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
df.shape
# Out:
# (6497, 13)

# %%
X = df.iloc[:,:-1]

# %%
X.head()
# Out:
#     type  fixed acidity  volatile acidity  ...    pH  sulphates  alcohol
# 0  white            7.0              0.27  ...  3.00       0.45      8.8
# 1  white            6.3              0.30  ...  3.30       0.49      9.5
# 2  white            8.1              0.28  ...  3.26       0.44     10.1
# 3  white            7.2              0.23  ...  3.19       0.40      9.9
# 4  white            7.2              0.23  ...  3.19       0.40      9.9
#
# [5 rows x 12 columns]

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 6492    5
# 6493    6
# 6494    6
# 6495    5
# 6496    6
# Name: quality, Length: 6497, dtype: int64

# %%
from time import time

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_score

# %%
model = RandomForestClassifier(n_estimators=100)

# %%
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=4)

# %%
X

# %%
start_time = time()
n_scores = cross_val_score(model, df.iloc[:,1:-1], df.iloc[:,-1], scoring='accuracy', cv=cv, n_jobs=1)
end_time = time()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   FitFailedWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   FitFailedWarning)
# ...
