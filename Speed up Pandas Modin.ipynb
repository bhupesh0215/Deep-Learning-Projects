# %%
# !pip install modin[ray]

# %%
import modin.pandas as pd

# %%
# %%time
df = pd.read_csv('/content/sample_data/esea_master_dmg_demos.part1.csv')
# Out:
# CPU times: user 146 ms, sys: 51.1 ms, total: 197 ms
# Wall time: 1.72 s

# %%
df.head()
# Out:
#                       file  round   tick  ...  att_pos_y  vic_pos_x  vic_pos_y
# 0  esea_match_13770997.dem      1  14372  ...    0.00000     0.0000   0.000000
# 1  esea_match_13770997.dem      1  15972  ...   63.33829  -669.5558 -79.769570
# 2  esea_match_13770997.dem      1  16058  ...    3.44563  -614.1868 -91.707770
# 3  esea_match_13770997.dem      1  16066  ...  -49.32681 -1065.5560   9.381622
# 4  esea_match_13770997.dem      1  16108  ...   49.19798  -748.4188 -53.469220
#
# [5 rows x 23 columns]

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: user 56.8 ms, sys: 23.4 ms, total: 80.2 ms
# Wall time: 642 ms
#                     file   round    tick  ...  att_pos_y  vic_pos_x  vic_pos_y
# att_team                                  ...
# Animal Style         362     362     362  ...        362        362        362
# Hentai Hooligans     389     389     389  ...        389        389        389
# Team 1            182459  182459  182459  ...     182458     182458     182458
# Team 2            177946  177946  177946  ...     177946     177946     177946
# World               3508    3508    3508  ...       3508       3508       3508
#
# [5 rows x 22 columns]
