# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/AI/ML/Datasets/mercedesbenz/mercedesbenz.csv', usecols=['X1', 'X2'])

# %%
df_freq_map = df.X2.value_counts().to_dict()

# %%
print(df.head)
df.X2 = df.X2.map(df_freq_map)
print(df.head)
# Out:
# <bound method NDFrame.head of      X1  X2
# 0     v  at
# 1     t  av
# 2     w   n
# 3     t   n
# 4     v   n
# ...  ..  ..
# 4204  s  as
# 4205  o   t
# 4206  v   r
# 4207  r   e
# 4208  r  ae
#
# [4209 rows x 2 columns]>
# <bound method NDFrame.head of      X1    X2
# 0     v     6
# 1     t     4
# 2     w   137
# 3     t   137
# 4     v   137
# ...  ..   ...
# 4204  s  1659
# 4205  o    29
# 4206  v   153
# 4207  r    81
# 4208  r   496
#
# [4209 rows x 2 columns]>
